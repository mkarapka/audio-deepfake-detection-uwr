# %%
import pandas as pd
from src.common.constants import Constants as consts

extracted_csv = consts.root / "data" / "extracted_embeddings.csv"

df = pd.read_csv(extracted_csv)

# %%
print(df.shape)
print(df.head())

# print column names
print(df.columns)
# Out:
# (22875, 4)
#        key_id                                               wave  duration  \
# 0  dev/1055_0  [-7.77767822e-02 -3.67689691e-03 -1.19759317e-...       4.0
# 1  dev/1055_0  [-6.74102455e-02  2.15571560e-02  1.89089160e-...       4.0
# 2  dev/1055_0  [-3.19475681e-02  7.11336657e-02 -1.56800617e-...       4.0
# 3  dev/1055_0  [-5.26344925e-02  3.67338359e-02  9.55703110e-...       4.0
# 4  dev/1055_0  [-4.53850329e-02  1.12713343e-02 -1.84585294e-...       4.0
#
#    starting_point
# 0             0.0
# 1             2.0
# 2             4.0
# 3             6.0
# 4             8.0
# Index(['key_id', 'wave', 'duration', 'starting_point'], dtype='object')

# %%
print(df['starting_point'])
# Out:
# 0        0.00
# 1        2.00
# 2        4.00
# 3        6.00
# 4        8.00
#          ...
# 22870    2.00
# 22871    4.00
# 22872    6.00
# 22873    8.00
# 22874    9.96
# Name: starting_point, Length: 22875, dtype: float64

# %%
import numpy as np
a = [1, 2, 3, 4, 5]

np.random.seed(42)
x = np.random.choice(a, 2, replace=False)
y = np.random.choice(a, 2, replace=False)

print(x)
print(y)

print(np.hstack([x, y]))
# Out:
# [2 5]
# [4 2]
# [2 5 4 2]

# %%
import torch

wav_size = 8000
waveform = torch.randn(1, wav_size)  # 0.5 seconds of audio at 16kHz
print(waveform.shape)

padded = torch.nn.functional.pad(waveform, (0,64_000 - wav_size))
print(padded.shape)
# Out:
# torch.Size([1, 8000])
# torch.Size([1, 64000])
