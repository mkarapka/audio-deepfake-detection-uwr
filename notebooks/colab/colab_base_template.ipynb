# %% [markdown]
# # Setting up Repo For Colab

# %%
# clone the repository
# !git clone https://github.com/mkarapka/audio-deepfake-detection-uwr.git

# install dependencies
# !cd audio-deepfake-detection-uwr && pip install uv && uv sync

# create data directories
# !cd audio-deepfake-detection-uwr/ && mkdir data
# !cd audio-deepfake-detection-uwr/ && mkdir data/collected_data
# !cd audio-deepfake-detection-uwr/ && mkdir data/collected_data/splited_data
# Out:
# Cloning into 'audio-deepfake-detection-uwr'...
# remote: Enumerating objects: 2108, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 2108 (delta 25), reused 36 (delta 21), pack-reused 2042 (from 2)
# Receiving objects: 100% (2108/2108), 77.27 MiB | 40.70 MiB/s, done.
# Resolving deltas: 100% (1413/1413), done.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.9/24.9 MB 112.3 MB/s eta 0:00:0000:0100:01
# ...
# Using CPython 3.12.13 interpreter at: /usr/bin/python3
# Creating virtual environment at: .venv
# Resolved 188 packages in 1ms
# Prepared 182 packages in 1m 15s
# Installed 182 packages in 283ms
#  + aiohappyeyeballs==2.6.1
#  + aiohttp==3.13.2
#  + aiosignal==1.4.0
#  + alembic==1.17.2
#  + annotated-types==0.7.0
#  + asttokens==3.0.1
#  + attrs==25.4.0
#  + audio-deepfake-detection-uwr==0.1.0 (from file:///content/audio-deepfake-detection-uwr)
#  + audioread==3.1.0
#  + autoflake==2.3.1
#  + autopep8==2.3.2
# ...

# %%
# !git clone https://huggingface.co/datasets/mueller91/In-The-Wild
# !mkidr /content/audio-deepfake-detection-uwr/data/in_the_wild
# !mkidr /content/audio-deepfake-detection-uwr/data/in_the_wild/audio

# !unzip /content/In-The-Wild/release_in_the_wild.zip -d /content/audio-deepfake-detection-uwr/data/in_the_wild/audio
# Out:
# Cloning into 'In-The-Wild'...
# remote: Enumerating objects: 17, done.
# remote: Total 17 (delta 0), reused 0 (delta 0), pack-reused 17 (from 1)
# Receiving objects: 100% (17/17), 5.85 KiB | 5.85 MiB/s, done.
# Resolving deltas: 100% (3/3), done.
# /bin/bash: line 1: mkidr: command not found
# /bin/bash: line 1: mkidr: command not found
# Archive:  /content/In-The-Wild/release_in_the_wild.zip
# checkdir:  cannot create extraction directory: /content/audio-deepfake-detection-uwr/data/in_the_wild/in_the_wild/audio
#            No such file or directory

# %%
# !unzip /content/In-The-Wild/release_in_the_wild.zip -d /content/audio-deepfake-detection-uwr/data/in_the_wild/audio
# Out:
# Archive:  /content/In-The-Wild/release_in_the_wild.zip
#    creating: /content/audio-deepfake-detection-uwr/data/in_the_wild/audio/release_in_the_wild/
#   inflating: /content/audio-deepfake-detection-uwr/data/in_the_wild/audio/release_in_the_wild/4054.wav
#   inflating: /content/audio-deepfake-detection-uwr/data/in_the_wild/audio/release_in_the_wild/2210.wav
#   inflating: /content/audio-deepfake-detection-uwr/data/in_the_wild/audio/release_in_the_wild/6418.wav
#   inflating: /content/audio-deepfake-detection-uwr/data/in_the_wild/audio/release_in_the_wild/30272.wav
#   inflating: /content/audio-deepfake-detection-uwr/data/in_the_wild/audio/release_in_the_wild/15101.wav
#   inflating: /content/audio-deepfake-detection-uwr/data/in_the_wild/audio/release_in_the_wild/6602.wav
#   inflating: /content/audio-deepfake-detection-uwr/data/in_the_wild/audio/release_in_the_wild/16153.wav
#   inflating: /content/audio-deepfake-detection-uwr/data/in_the_wild/audio/release_in_the_wild/23183.wav
# ...

# %%
# !mv /content/audio-deepfake-detection-uwr/data/in_the_wild/audio/release_in_the_wild/* /content/audio-deepfake-detection-uwr/data/in_the_wild/audio/
# Out:
# /bin/bash: line 1: /usr/bin/mv: Argument list too long

# %%
# Loading the package from the repository
import sys

root_path = "/content/audio-deepfake-detection-uwr"
path = f"{root_path}/.venv/lib/python3.12/site-packages"

sys.path.insert(0, path)
sys.path.append(root_path)
sys.path.append(f"{root_path}/src")

# %%
# check cpu info
# !echo "CPU INFO:" && lscpu | grep "Model name" && lscpu | grep "Architecture"
# Out:
# CPU INFO:
# Model name:                              Intel(R) Xeon(R) CPU @ 2.20GHz
# Architecture:                            x86_64

# %% [markdown]
# ## Loading files from google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !mkdir /content/audio-deepfake-detection-uwr/data/in_the_wild
# !mkdir /content/audio-deepfake-detection-uwr/data/in_the_wild/audio
# !cp /content/drive/MyDrive/deepfake_data/in_the_wild_meta.csv /content/audio-deepfake-detection-uwr/data/in_the_wild/in_the_wild.csv

# %%
# !cp /content/drive/MyDrive/deepfake_data/speakers_ids.csv /content/audio-deepfake-detection-uwr/data/collected_data/speakers_ids.csv

# !cp /content/drive/MyDrive/deepfake_data/feature_extracted.csv /content/audio-deepfake-detection-uwr/data/collected_data/feature_extracted.csv
# !cp /content/drive/MyDrive/deepfake_data/feature_extracted_train.csv /content/audio-deepfake-detection-uwr/data/collected_data/splited_data/feature_extracted_train.csv
# !cp /content/drive/MyDrive/deepfake_data/feature_extracted_dev.csv /content/audio-deepfake-detection-uwr/data/collected_data/splited_data/feature_extracted_dev.csv
# !cp /content/drive/MyDrive/deepfake_data/feature_extracted_test.csv /content/audio-deepfake-detection-uwr/data/collected_data/splited_data/feature_extracted_test.csv

# %%
feature_extracted_suffix = "_wavlm"
file_name_no_ext = f"feature_extracted{feature_extracted_suffix}"

# %%
feature_extracted_suffix = "_fft"
file_name_no_ext = f"feature_extracted{feature_extracted_suffix}"

# %%
# !cp /content/drive/MyDrive/deepfake_data/{file_name_no_ext}.npy /content/audio-deepfake-detection-uwr/data/collected_data/{file_name_no_ext}.npy

# %% [markdown]
# ## Saving files to google drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp /content/audio-deepfake-detection-uwr/data/collected_data/speakers_ids.csv /content/drive/MyDrive/deepfake_data/speakers_ids.csv

# !cp /content/audio-deepfake-detection-uwr/data/collected_data/feature_extracted.csv /content/drive/MyDrive/deepfake_data/feature_extracted.csv
# !cp /content/audio-deepfake-detection-uwr/data/collected_data/splited_data/feature_extracted_train.csv /content/drive/MyDrive/deepfake_data/feature_extracted_train.csv
# !cp /content/audio-deepfake-detection-uwr/data/collected_data/splited_data/feature_extracted_dev.csv /content/drive/MyDrive/deepfake_data/feature_extracted_dev.csv
# !cp /content/audio-deepfake-detection-uwr/data/collected_data/splited_data/feature_extracted_test.csv /content/drive/MyDrive/deepfake_data/feature_extracted_test.csv

# %%
feature_extracted_suffix = "_wavlm"
file_name_no_ext = f"feature_extracted{feature_extracted_suffix}"

# %%
feature_extracted_suffix = "_fft"
file_name_no_ext = f"feature_extracted{feature_extracted_suffix}"

# %%
# !cp /content/audio-deepfake-detection-uwr/data/collected_data/{file_name_no_ext}.npy /content/drive/MyDrive/deepfake_data/{file_name_no_ext}.npy

# %% [markdown]
# # Evaluation

# %%
# !cp /content/audio-deepfake-detection-uwr/data/collected_data/in_the_wild.csv /content/drive/MyDrive/deepfake_data/in_the_wild_metadata.csv

# %%
# !cp /content/audio-deepfake-detection-uwr/data/collected_data/in_the_wild_wavlm.npy /content/drive/MyDrive/deepfake_data/in_the_wild_wavlm.npy

# %%
# !cp /content/audio-deepfake-detection-uwr/data/collected_data/in_the_wild_fft.npy /content/drive/MyDrive/deepfake_data/in_the_wild_fft.npy
